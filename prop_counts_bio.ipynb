# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import sys, os
sys.path.insert(0, "/home/gstupp/projects/WikidataIntegrator")
from wikidataintegrator import wdi_core, wdi_helpers
pd.options.display.max_columns = 100
pd.options.display.max_rows = 200
# %pylab
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
prop_df = pd.read_csv("prop_count_labels.csv", index_col=0)
prop_df.head()
# Out:
#                        unique     total  organic  organic__total   robotic  \
# PubMed ID            14939845  15752202      515            3103  14939322
# PMCID                 7681907  10052851       58             150   7681848
# instance of           5372473  21619474   124368          288786   5243926
# subclass of           3714982  15840791    51449          112441   3660835
# coordinate location   1237332   7305262    35464          213065   1201069
#
#                      robotic__total  PBB_core fastrun  Java/1.7.0  \
# PubMed ID                  15703193          14933216           0
# PMCID                      10052511           7677869           0
# instance of                20053361             88159         402
# subclass of                15422687            114167        1563
# coordinate location         7063722                 0      778520
#
#                      Pywikibot/3.0-dev__total  Asparagus/Asparagus 0.1  \
# PubMed ID                                   0                        0
# PMCID                                       0                        0
# instance of                           1912254                     1261
# subclass of                            286998                        0
# coordinate location                      5756                        0
#
#                      jgonsior-tree  __match_taxon  \
# PubMed ID                        0              0
# PMCID                            0              0
# instance of                      0              0
# subclass of                     10              0
# coordinate location              0              0
#
#                      images_on_wikidata_not_wikipedia__total  C++ WikiAPI  \
# PubMed ID                                                  0           12
# PMCID                                                      0           10
# instance of                                           130480            8
# subclass of                                                0            1
# coordinate location                                        0            0
#
#                      botanists__total  okhttp/3.4.1__total  axios__total  \
# PubMed ID                           0                    0             0
# PMCID                               0                    0             0
# instance of                         0                17663            24
# subclass of                         0                 1348             0
# coordinate location                 0                    0             0
#
#                      testing  \
# PubMed ID                  0
# PMCID                      0
# instance of                5
# subclass of                0
# coordinate location        0
#
#                      Jersey/2.22.1 (HttpUrlConnection 1.8.0_45)__total  \
# PubMed ID                                                            0
# PMCID                                                                0
# instance of                                                          0
# subclass of                                                          0
# coordinate location                                                  0
#
#                      browser__total  microsync  \
# PubMed ID                     49009          0
# PMCID                           340          0
# instance of                 4776987          0
# subclass of                 3004434          0
# coordinate location         1302712          0
#
#                      kartotherian-geoshapes/0.0.10 (https://mediawiki.org/Maps)__total  \
# PubMed ID                                                            0
# PMCID                                                                0
# instance of                                                      89282
# subclass of                                                      88206
# coordinate location                                              17156
#
#                       Ruby  __find_genus  orcid_bot  \
# PubMed ID                0             0          0
# PMCID                    0             0          0
# instance of          21318             0         13
# subclass of          30748             0          0
# coordinate location      4             0          0
#
#                      Mechanize/2.7.5 Ruby/2.2.7p470 (http://github.com/sparklemotion/mechanize/)  \
# PubMed ID                                                            0
# PMCID                                                                0
# instance of                                                          0
# subclass of                                                          0
# coordinate location                                                  0
#
#                      other__total  Java/1.7.0__total  \
# PubMed ID                      10                  0
# PMCID                          11                  0
# instance of                 80457               1380
# subclass of                 38507               5512
# coordinate location          9539            1818522
#
#                      Jakarta Commons-HttpClient/3.1  orcidator  \
# PubMed ID                                         0          0
# PMCID                                             0          0
# instance of                                   62042          0
# subclass of                                      97          0
# coordinate location                            1169          0
#
#                      resolver__total  __match_taxon__total  Apache-Jena-ARQ  \
# PubMed ID                          0                     0               78
# PMCID                              7                     0               74
# instance of                        0                     0           158908
# subclass of                        1                     0            10289
# coordinate location                0                     0           137540
#
#                      other  Python-httplib2__total  \
# PubMed ID                2                       0
# PMCID                    2                       0
# instance of           9622                     296
# subclass of          10887                       0
# coordinate location   3840                       0
#
#                      sparqlwrapper * (rdflib.github.io/sparqlwrapper)  \
# PubMed ID                                                        2033
# PMCID                                                               2
# instance of                                                   1705984
# subclass of                                                   1644043
# coordinate location                                             14298
#
#                      MovieGuide-wikidata/0.1__total  fix_items  \
# PubMed ID                                         0         99
# PMCID                                             0       2099
# instance of                                       0          0
# subclass of                                       0          0
# coordinate location                               0          0
#
#                      python-requests__total  bot_commons  auxiliary_matcher  \
# PubMed ID                               692            0                  0
# PMCID                                   682            0                  0
# instance of                         5614880            2                  0
# subclass of                         4494721            0                  0
# coordinate location                  615196            0               3459
#
#                      okhttp/3.4.1  wd_edit_stats__total  automatch  \
# PubMed ID                       0                     0          0
# PMCID                           0                     0          0
# instance of                  3230                   824          0
# subclass of                  1125                     0         19
# coordinate location             0                     1          0
#
#                      Pywikibot/3.0-dev       -  \
# PubMed ID                            0       7
# PMCID                                0       7
# instance of                     196660  785474
# subclass of                     158831  117715
# coordinate location                 26   69185
#
#                      BeeMusic.Importer (https://beemusic.kantarmedia.fr/; *)  \
# PubMed ID                                                            0
# PMCID                                                                0
# instance of                                                          0
# subclass of                                                          0
# coordinate location                                                  0
#
#                      QueryBot/0.1  beacon__total  \
# PubMed ID                       0              0
# PMCID                           0              0
# instance of                105520              0
# subclass of                105517              0
# coordinate location             0              0
#
#                      node-fetch/1.0 (+https://github.com/bitinn/node-fetch)__total  \
# PubMed ID                                                            0
# PMCID                                                                0
# instance of                                                     114157
# subclass of                                                     228154
# coordinate location                                                  0
#
#                               ...             resolver  beaTunes__total  \
# PubMed ID                     ...                    0                0
# PMCID                         ...                    6                0
# instance of                   ...                    0           185891
# subclass of                   ...                    1           111156
# coordinate location           ...                    0                0
#
#                      update_dynamic__total  \
# PubMed ID                                0
# PMCID                                    0
# instance of                           2353
# subclass of                           1011
# coordinate location                      0
#
#                      node-fetch/1.0 (+https://github.com/bitinn/node-fetch)  \
# PubMed ID                                                            0
# PMCID                                                                0
# instance of                                                      10552
# subclass of                                                      21100
# coordinate location                                                  0
#
#                      kartotherian-geoshapes/0.0.10 (https://mediawiki.org/Maps)  \
# PubMed ID                                                            0
# PMCID                                                                0
# instance of                                                       7584
# subclass of                                                       7499
# coordinate location                                               2675
#
#                      misc  misc__total  botanists  testing__total  PetScan  \
# PubMed ID               0            0          0               0        0
# PMCID                   0            0          0               0        1
# instance of             0            0          0             822    16704
# subclass of             0            0          0               0      331
# coordinate location     0            0          0               0      104
#
#                      thorough_name_match__total  python-requests  \
# PubMed ID                                     0                4
# PMCID                                         0                2
# instance of                                   0          1314288
# subclass of                                   0           756168
# coordinate location                           0             6299
#
#                      taxon_matcher  PetScan__total  robotic,organic__total  \
# PubMed ID                        0               0                   45906
# PMCID                            0             251                     190
# instance of                   1108           44632                 1277327
# subclass of                    540            1718                  305663
# coordinate location              0             598                   28475
#
#                      auxiliary_matcher__total  YTCleaner  C++ WikiAPI__total  \
# PubMed ID                                   0          0                 120
# PMCID                                       0          0                1204
# instance of                                 0          0                 323
# subclass of                                 0          0                  44
# coordinate location                   2201348          0                   0
#
#                      Java/1.6.0__total  Python-urllib__total  \
# PubMed ID                            0                     0
# PMCID                                0                     0
# instance of                          0               1677430
# subclass of                          0                203038
# coordinate location                  0                  6742
#
#                      SQID Python Helper  YTCleaner__total  \
# PubMed ID                             0                 0
# PMCID                                 0                 0
# instance of                           2                 0
# subclass of                           0                 0
# coordinate location                   0                 0
#
#                      MediaWiki/1.30.0-wmf.*  query__total  \
# PubMed ID                              3678             0
# PMCID                                  1600             0
# instance of                               0           716
# subclass of                           13629           178
# coordinate location                   82324           135
#
#                      https://github.com/bearloga/WikidataQueryServiceR__total  \
# PubMed ID                                                           28
# PMCID                                                                0
# instance of                                                       4652
# subclass of                                                       4192
# coordinate location                                               3372
#
#                      MediaWiki/1.30.0-wmf.*__total  query  Java/1.6.0  \
# PubMed ID                                     4964      0           0
# PMCID                                         2070      0           0
# instance of                                      0    260           0
# subclass of                                 851438     52           0
# coordinate location                         134508     68           0
#
#                      new_resolve_authors__total  \
# PubMed ID                                     0
# PMCID                                         0
# instance of                               11450
# subclass of                                   0
# coordinate location                           0
#
#                      Jakarta Commons-HttpClient/3.1__total  Magnus labs tools  \
# PubMed ID                                                0                199
# PMCID                                                    0                179
# instance of                                         174722               8627
# subclass of                                           1180               1226
# coordinate location                                  22782               1737
#
#                      Java/1.8.0__total  Python-httplib2  wd_edit_stats  \
# PubMed ID                            0                0              0
# PMCID                                0                0              0
# instance of                     498535                1             10
# subclass of                     640772                0              0
# coordinate location               4098                0              1
#
#                      Jersey/2.22.1 (HttpUrlConnection 1.8.0_45)  beacon  \
# PubMed ID                                                     0       0
# PMCID                                                         0       0
# instance of                                                   0       0
# subclass of                                                   0       0
# coordinate location                                           0       0
#
#                      Java/1.8.0  __match_or_create_species  coords2json  \
# PubMed ID                     0                          0            0
# PMCID                         0                          0            0
# instance of               27848                          0            0
# subclass of               23196                          0            0
# coordinate location        1348                          0           27
#
#                      BeeMusic.Importer (https://beemusic.kantarmedia.fr/; *)__total  \
# PubMed ID                                                            0
# PMCID                                                                0
# instance of                                                          0
# subclass of                                                          0
# coordinate location                                                  0
#
#                      orcidator__total  translate_items_with_property__total  \
# PubMed ID                           0                                     0
# PMCID                               0                                     0
# instance of                         0                                     6
# subclass of                         0                                     0
# coordinate location                 0                                     0
#
#                      robotic,organic  \
# PubMed ID                          8
# PMCID                              1
# instance of                     4179
# subclass of                     2698
# coordinate location              799
#
#                      osm-wikidata/0.1 (https://github.com/EdwardBetts/osm-wikidata; *)  \
# PubMed ID                                                            0
# PMCID                                                                0
# instance of                                                     196322
# subclass of                                                     196322
# coordinate location                                                594
#
#                      jgonsior-tree__total  taxon_matcher__total  \
# PubMed ID                               0                     0
# PMCID                                   0                     0
# instance of                             0                208670
# subclass of                          1640                104045
# coordinate location                     0                     0
#
#                      update_dynamic  awarder  -__total  \
# PubMed ID                         0        0         7
# PMCID                             0        0         7
# instance of                       7        1   2312978
# subclass of                       3        1    516525
# coordinate location               0        0    313574
#
#                      missing_wp_animal_audio
# PubMed ID                                  0
# PMCID                                      0
# instance of                                3
# subclass of                                0
# coordinate location                        0
#
# [5 rows x 142 columns]

# %%
# biomedical properties
PROPS = ['genomic assembly', 'FlyBase Gene ID', 'found in taxon', 'CAS Registry Number', 'ortholog', 'PMCID', 'chemical formula', 'statement disputed by', 'NCI Thesaurus ID', 
         'anatomical location', 'HGNC gene symbol', 'Rat Genome Database ID', 'UBERON ID', 'has cause', 'Saccharomyces Genome Database ID', 'IEDB Epitope ID', 'Refseq Genome ID', 
         'Guide to Pharmacology Ligand ID', 'biological process', 'ICD-10', 'InChI', 'medical condition treated', 'Drugbank ID', 'genomic end', 'ZFIN Gene ID', 'NDF-RT ID', 
         'encoded by', 'miRBase mature miRNA ID', 'NCBI Locus tag', 'DOI', 'parent taxon', 'UniProt protein ID', 'curator', 'positive diagnostic predictor', 'negative therapeutic predictor',
         'biological variant of', 'HGNC ID', 'genetic association', 'OMIM ID', 'HGVS nomenclature', 'InterPro ID', 'MeSH Code', 'ChemSpider ID', 'RefSeq Protein ID', 'positive prognostic predictor', 
         'PDB structure ID', 'Human Phenotype Ontology ID', 'negative diagnostic predictor', 'EC enzyme number', 'Sequence Ontology ID', 'ChEBI ID', 'ChEMBL ID', 'symptoms', 'determination method', 
         'chromosome', 'miRBase pre-miRNA ID', 'cytogenetic location', 'ICD-10-CM', 'InChIKey', 'molecular function', 'cell component', 'ICD-9-CM', 'rating', 'encodes', 'Wormbase Gene ID', 'ATC code', 
         'isomeric SMILES', 'archive URL', 'GARD rare disease ID', 'RefSeq RNA ID', 'MGI Gene Symbol', 'equivalent class', 'MeSH ID', 'regulates (molecular biology)', 'develops from', 'ICD-9', 
         'negative prognostic predictor', 'UMLS CUI', 'route of administration', 'mirTarBase ID', 'Mouse Genome Informatics ID', 'taxon name', 'Entrez Gene ID', 'strand orientation', 'UNII', 'MonDO ID', 
         'National Cancer Institute ID', 'Ensembl Gene ID', 'Ensembl Transcript ID', 'PubMed ID', 'retrieved', 'Gene Ontology ID', 'positive therapeutic predictor', 'HomoloGene ID', 'Ensembl Protein ID', 
         'genomic start', 'NCBI Taxonomy ID', 'PubChem CID', 'canonical SMILES', 'Orphanet ID', 'subject has role', 'RTECS number', 'Disease Ontology ID', 'KEGG ID', 'CIViC variant ID']
bm_prop_df = prop_df.reindex(PROPS).sort_values("PBB_core fastrun", ascending=False).dropna(axis=0, how="all").dropna(axis=1, how="all").astype(int)

# %%
total = bm_prop_df.sum(axis=0)
cols = bm_prop_df.columns[total>1000]
bm_prop_df = bm_prop_df[cols]
bm_prop_df.to_csv("bm_prop_df.csv")
bm_prop_df.head()
# Out:
#                       unique     total  organic  organic__total   robotic  \
# PubMed ID           14939845  15752202      515            3103  14939322
# PMCID                7681907  10052851       58             150   7681848
# UniProt protein ID    970273   1666935     1039            7226    969218
# Entrez Gene ID        299413    705165     1356            8420    298042
# RefSeq RNA ID         213504   1307474        2               2    213500
#
#                     robotic__total  PBB_core fastrun  \
# PubMed ID                 15703193          14933216
# PMCID                     10052511           7677869
# UniProt protein ID         1659181            968115
# Entrez Gene ID              696312            295447
# RefSeq RNA ID               367132            212308
#
#                     Pywikibot/3.0-dev__total  browser__total  other__total  \
# PubMed ID                                  0           49009            10
# PMCID                                      0             340            11
# UniProt protein ID                         0           14435            58
# Entrez Gene ID                             0            8853           135
# RefSeq RNA ID                              0          940342            10
#
#                     orcidator  resolver__total  __match_taxon__total  \
# PubMed ID                   0                0                     0
# PMCID                       0                7                     0
# UniProt protein ID          0                0                     0
# Entrez Gene ID              0                2                     0
# RefSeq RNA ID               0                0                     0
#
#                     Apache-Jena-ARQ  other  \
# PubMed ID                        78      2
# PMCID                            74      2
# UniProt protein ID               74      6
# Entrez Gene ID                   74     15
# RefSeq RNA ID                    59      2
#
#                     sparqlwrapper * (rdflib.github.io/sparqlwrapper)  \
# PubMed ID                                                       2033
# PMCID                                                              2
# UniProt protein ID                                                18
# Entrez Gene ID                                                  2009
# RefSeq RNA ID                                                      0
#
#                     fix_items  python-requests__total  auxiliary_matcher  -  \
# PubMed ID                  99                     692                  0  7
# PMCID                    2099                     682                  0  7
# UniProt protein ID          0                       0                  0  6
# Entrez Gene ID              0                     104                  0  6
# RefSeq RNA ID               0                       0                  0  5
#
#                     beacon__total  \
# PubMed ID                       0
# PMCID                           0
# UniProt protein ID            244
# Entrez Gene ID                244
# RefSeq RNA ID                   0
#
#                     sparqlwrapper * (rdflib.github.io/sparqlwrapper)__total  \
# PubMed ID                                                       30861
# PMCID                                                               2
# UniProt protein ID                                                181
# Entrez Gene ID                                                  10999
# RefSeq RNA ID                                                       0
#
#                     Apache-Jena-ARQ__total  Python-urllib  Apache-HttpClient  \
# PubMed ID                               78              0                  0
# PMCID                                   74              0                  0
# UniProt protein ID                      74              0                  0
# Entrez Gene ID                         288              0                  0
# RefSeq RNA ID                           59              0                  0
#
#                     fix_items__total  Apache-HttpClient__total  browser  \
# PubMed ID                         99                         0      523
# PMCID                           2110                         0       59
# UniProt protein ID                 0                         0     1759
# Entrez Gene ID                     0                         0     1371
# RefSeq RNA ID                      0                         0        4
#
#                     PBB_core fastrun__total  orcid_bot__total  \
# PubMed ID                          15711819                 0
# PMCID                              10046060                 0
# UniProt protein ID                  1651953                 0
# Entrez Gene ID                       684245                 0
# RefSeq RNA ID                       1305434                 0
#
#                     Magnus labs tools__total  \
# PubMed ID                                421
# PMCID                                    486
# UniProt protein ID                         0
# Entrez Gene ID                             0
# RefSeq RNA ID                              0
#
#                     __match_or_create_species__total  python-requests  \
# PubMed ID                                          0                4
# PMCID                                              0                2
# UniProt protein ID                                 0                0
# Entrez Gene ID                                     0                4
# RefSeq RNA ID                                      0                0
#
#                     taxon_matcher  robotic,organic__total  \
# PubMed ID                       0                   45906
# PMCID                           0                     190
# UniProt protein ID              0                     528
# Entrez Gene ID                  0                     433
# RefSeq RNA ID                   0                  940340
#
#                     auxiliary_matcher__total  C++ WikiAPI__total  \
# PubMed ID                                  0                 120
# PMCID                                      0                1204
# UniProt protein ID                         0                 148
# Entrez Gene ID                             0                 148
# RefSeq RNA ID                              0                 146
#
#                     Python-urllib__total  MediaWiki/1.30.0-wmf.*  \
# PubMed ID                              0                    3678
# PMCID                                  0                    1600
# UniProt protein ID                     0                     262
# Entrez Gene ID                         0                     454
# RefSeq RNA ID                          0                    1118
#
#                     MediaWiki/1.30.0-wmf.*__total  Magnus labs tools  \
# PubMed ID                                    4964                199
# PMCID                                        2070                179
# UniProt protein ID                            368                  0
# Entrez Gene ID                                678                  0
# RefSeq RNA ID                                1818                  0
#
#                     orcidator__total  taxon_matcher__total  -__total
# PubMed ID                          0                     0         7
# PMCID                              0                     0         7
# UniProt protein ID                 0                     0         6
# Entrez Gene ID                     0                     0         6
# RefSeq RNA ID                      0                     0         5

# %%
bm_prop_df_log = bm_prop_df.apply(lambda x:np.log10(x+1))

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(211)
df = bm_prop_df_log.sort_values("total")[-15:]
df[['total']].plot.barh(ax=ax, legend=False)
ax2 = fig.add_subplot(212)
df = bm_prop_df_log.sort_values("unique")[-15:]
df[['unique']].plot.barh(ax=ax2, legend=False)
ax.set_title("Total Count")
ax2.set_title("Unique Count")
ax2.set_xlabel("Log(Count)")

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(211)
df = bm_prop_df_log.sort_values("organic")[-15:]
df[['organic']].plot.barh(ax=ax, legend=False)
ax2 = fig.add_subplot(212)
df = bm_prop_df_log.sort_values("robotic")[-15:]
df[['robotic']].plot.barh(ax=ax2, legend=False)
ax.set_title("Organic Count")
ax2.set_title("Robotic Count")
ax2.set_xlabel("Log(Count)")

# %%
ua_cols = set(bm_prop_df_log.columns)-{'unique', 'total', 'organic', 'organic__total', 'robotic', 'robotic__total', 'robotic,organic__total', 'robotic,organic', 'label'}

ua_prop_df = bm_prop_df_log.loc[:,ua_cols]
ua_prop_df_total = ua_prop_df[ua_prop_df.columns[ua_prop_df.columns.str.contains("__total")]]
ua_prop_df_total.columns = ua_prop_df_total.columns.str.replace("__total", "")
ua_prop_df_unique = ua_prop_df[ua_prop_df.columns[~ua_prop_df.columns.str.contains("__total")]]

top_props = set(ua_prop_df_total.sum(axis=1).sort_values(ascending=False)[:10].index) | set(ua_prop_df_unique.sum(axis=1).sort_values(ascending=False)[:10].index)
ua_prop_df_total = ua_prop_df_total[ua_prop_df_total.index.isin(top_props)]
ua_prop_df_unique = ua_prop_df_unique[ua_prop_df_unique.index.isin(top_props)]

top_uas_total = ua_prop_df_total.sum(axis=0).sort_values(ascending=False)[:9].index
top_uas_unique = ua_prop_df_unique.sum(axis=0).sort_values(ascending=False)[:9].index
ua_prop_df_total = ua_prop_df_total.loc[:, top_uas_total]
ua_prop_df_unique = ua_prop_df_unique.loc[:, top_uas_unique]

# %%
m = ua_prop_df_total.reset_index().melt(id_vars="index")
g = sns.FacetGrid(m, col="variable", col_wrap=3, height=2.5, aspect=2)
g.map(sns.stripplot, "value", "index", size=10)
g.set(xlim=(-0.1, 8))
for ax in g.axes:
    ax.grid(color='r', linestyle='-', linewidth=1, axis='y')
g.set_xlabels("log(count)")
# Out:
# /usr/local/lib/python3.5/dist-packages/seaborn/axisgrid.py:715: UserWarning: Using the stripplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
m = ua_prop_df_unique.reset_index().melt(id_vars="index")
g = sns.FacetGrid(m, col="variable", col_wrap=3, height=2.5, aspect=2)
g.map(sns.stripplot, "value", "index", size=10)
g.set(xlim=(-0.1, 8))
for ax in g.axes:
    ax.grid(color='r', linestyle='-', linewidth=1, axis='y')
g.set_xlabels("log(count)")
# Out:
# /usr/local/lib/python3.5/dist-packages/seaborn/axisgrid.py:715: UserWarning: Using the stripplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
